# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('./mushrooms.csv')
data.shape
# Out:
# (8124, 23)

# %%
data.head()
# Out:
#    type  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0     1          5            2          4        1     6                1
# 1     0          5            2          9        1     0                1
# 2     0          0            2          8        1     3                1
# 3     1          5            3          8        1     6                1
# 4     0          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color   ...     stalk_surface_below_ring  \
# 0             0          1           4   ...                            2
# 1             0          0           4   ...                            2
# 2             0          0           5   ...                            2
# 3             0          1           5   ...                            2
# 4             1          0           4   ...                            2
#
# ...

# %%
le = LabelEncoder()
df = data.apply(le.fit_transform)

# %%
print (df)
# Out:
#       type  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0        1          5            2          4        1     6                1
# 1        0          5            2          9        1     0                1
# 2        0          0            2          8        1     3                1
# 3        1          5            3          8        1     6                1
# 4        0          5            2          3        0     5                1
# 5        0          5            3          9        1     0                1
# 6        0          0            2          8        1     0                1
# 7        0          0            3          8        1     3                1
# 8        1          5            3          8        1     6                1
# 9        0          0            2          9        1     0                1
# 10       0          5            3          9        1     3                1
# ...

# %%
data = df.values

# %%
print(data.shape)
# Out:
# (8124, 23)

# %%
xdata = data[:,1:]
ydata = data[:,0]
print(xdata.shape,ydata.shape)
# Out:
# (8124, 22) (8124,)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(xdata,ydata,test_size=0.2,random_state = 2)
print(xtrain.shape,ytrain.shape,xtest.shape,ytest.shape)
# Out:
# (6499, 22) (6499,) (1625, 22) (1625,)

# %% [markdown]
# # Code for Naive Bayes classifier

# %%
def prior_prob(ytrain, label):
    return np.sum(ytrain==label)/ytrain.shape[0]

# %%
prior_prob(ytrain,1)
# Out:
# 0.48115094629943067

# %%
def cond_prob(x_train,y_train,feature_col, feature_val, label):
    
    xfilt = x_train[y_train==label]
    constraint= np.sum(xfilt[:,feature_col]==feature_val)
    prob_value = constraint/float(xfilt.shape[0])
    return prob_value

# %%
def predict(x_train,y_train,x_test):
    preds = []
    classes = np.unique(ytrain)
    for ix in range(x_test.shape[0]):
        post_prob = []
    
        for jx in classes:
            likelihood = 1.0
#         print(x_test[ix])
            for kx in range(x_test[ix].shape[0]):
                cond = cond_prob(x_train,y_train,kx,x_test[ix,kx],jx)
                likelihood *= cond
            prior = prior_prob(y_train,jx)
            posterior_prob = likelihood*prior
#         print(posterior_prob)
            post_prob.append(posterior_prob)
        post_prob = np.array(post_prob)
#     print(post_prob)
        pred_label = post_prob.argmax()
        preds.append(pred_label)
    return preds

# %%
predictions = predict(xtrain,ytrain,xtest)

# %%
np.sum(predictions==ytest)/ytest.shape[0]
# Out:
# 0.99446153846153851
