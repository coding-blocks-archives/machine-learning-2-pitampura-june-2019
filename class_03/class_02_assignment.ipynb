# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
list_ran = []
for ix in range(1000):
    x = np.random.random()
    if x <= 0.5:
        list_ran.append("a")
    if x > 0.5 and x <= 0.7:
        list_ran.append("b")
    if x > 0.7:
        list_ran.append("c")

# %%
np.unique(list_ran, return_counts=True)
# Out:
# (array(['a', 'b', 'c'], dtype='<U1'), array([492, 196, 312]))

# %%
x = np.random.multivariate_normal([1.0, 0.5], [[1.0, -1.5],[-1.5, 1.5]], 1000)
# Out:
# /home/vasu/all_projects/calculai/RC/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   """Entry point for launching an IPython kernel.

# %%
plt.scatter(x[:,0],x[:,1])

# %%
std_x = (x - x.mean())/x.std()

# %%
plt.scatter(std_x[:,0], std_x[:,1], c='b')
